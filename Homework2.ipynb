# %%
import pandas as pd
import seaborn as sns

# %%
# load data
data = pd.read_csv("senate_results.csv")

# %%
# compute correlation matrix
corr_matrix = data.corr()

# %%
# visualize correlation matrix as a heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
# interpret correlation coefficients
for col in corr_matrix.columns:
    corr_values = corr_matrix[col].sort_values(ascending=False)
    print("Correlations for", col)
    print(corr_values)
# Out:
# Correlations for year
# year              1.000000
# writein           0.163305
# totalvotes        0.126644
# special           0.110265
# unofficial        0.074164
# state_ic          0.048867
# state_cen         0.048094
# candidatevotes    0.021223
# state_fips       -0.043489
# version                NaN
# Name: year, dtype: float64
# Correlations for state_fips
# state_fips        1.000000
# unofficial        0.016871
# candidatevotes   -0.035420
# year             -0.043489
# state_ic         -0.087146
# special          -0.090493
# writein          -0.116782
# totalvotes       -0.127496
# state_cen        -0.191282
# version                NaN
# Name: state_fips, dtype: float64
# Correlations for state_cen
# state_cen         1.000000
# state_ic          0.963486
# special           0.051812
# year              0.048094
# writein           0.017702
# unofficial        0.001668
# candidatevotes    0.000063
# totalvotes       -0.083751
# state_fips       -0.191282
# version                NaN
# Name: state_cen, dtype: float64
# Correlations for state_ic
# state_ic          1.000000
# state_cen         0.963486
# special           0.049050
# year              0.048867
# writein           0.032452
# unofficial        0.015982
# candidatevotes   -0.004517
# state_fips       -0.087146
# totalvotes       -0.088696
# version                NaN
# Name: state_ic, dtype: float64
# Correlations for special
# special           1.000000
# year              0.110265
# totalvotes        0.062188
# writein           0.061834
# state_cen         0.051812
# state_ic          0.049050
# unofficial        0.045959
# candidatevotes   -0.011498
# state_fips       -0.090493
# version                NaN
# Name: special, dtype: float64
# Correlations for writein
# writein           1.000000
# year              0.163305
# special           0.061834
# totalvotes        0.057280
# state_ic          0.032452
# state_cen         0.017702
# unofficial       -0.019280
# state_fips       -0.116782
# candidatevotes   -0.202556
# version                NaN
# Name: writein, dtype: float64
# Correlations for candidatevotes
# candidatevotes    1.000000
# totalvotes        0.432303
# unofficial        0.044728
# year              0.021223
# state_cen         0.000063
# state_ic         -0.004517
# special          -0.011498
# state_fips       -0.035420
# writein          -0.202556
# version                NaN
# Name: candidatevotes, dtype: float64
# Correlations for totalvotes
# totalvotes        1.000000
# candidatevotes    0.432303
# year              0.126644
# special           0.062188
# writein           0.057280
# unofficial        0.001445
# state_cen        -0.083751
# state_ic         -0.088696
# state_fips       -0.127496
# version                NaN
# Name: totalvotes, dtype: float64
# Correlations for unofficial
# unofficial        1.000000
# year              0.074164
# special           0.045959
# candidatevotes    0.044728
# state_fips        0.016871
# state_ic          0.015982
# state_cen         0.001668
# totalvotes        0.001445
# writein          -0.019280
# version                NaN
# Name: unofficial, dtype: float64
# Correlations for version
# year             NaN
# state_fips       NaN
# state_cen        NaN
# state_ic         NaN
# special          NaN
# writein          NaN
# candidatevotes   NaN
# totalvotes       NaN
# unofficial       NaN
# version          NaN
# Name: version, dtype: float64
